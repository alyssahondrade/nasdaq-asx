# %%
# Import dependencies
import pandas as pd
from pathlib import Path

# %%
# Define the path to the csv
asx_path = Path("Resources/asx-companies-list.csv")
nasdaq_path = Path("Resources/nasdaq-companies-list.csv")

# %%
# Create ASX DataFrame
asx_df = pd.read_csv(asx_path)
asx_df
# Out:
#          Code                                Company  \
# 0     ASX:BHP            BHP Group Limited (ASX:BHP)
# 1     ASX:CBA            Commonwealth Bank (ASX:CBA)
# 2     ASX:CSL                  CSL Limited (ASX:CSL)
# 3     ASX:NAB      National Australia Bank (ASX:NAB)
# 4     ASX:ANZ   ANZ Group Holdings Limited (ASX:ANZ)
# ...       ...                                    ...
# 2760  ASX:RCO            Royalco Resources (ASX:RCO)
# 2761  ASX:CVO             Cover-More Group (ASX:CVO)
# 2762  ASX:AYS            Amaysim Australia (ASX:AYS)
# 2763  ASX:BAL  Bellamy's Australia Limited (ASX:BAL)
# 2764  ASX:DET                Dealt Limited (ASX:DET)
#
#                                                    Link    Market Cap  \
# 0     https://www.listcorp.com/asx/bhp/bhp-group-lim...  225204000000
# 1     https://www.listcorp.com/asx/cba/commonwealth-...  165522000000
# 2          https://www.listcorp.com/asx/csl/csl-limited  112598000000
# 3                  https://www.listcorp.com/asx/nab/nab   89644400000
# 4     https://www.listcorp.com/asx/anz/anz-group-hol...   75943600000
# ...                                                 ...           ...
# 2760  https://www.listcorp.com/asx/rco/royalco-resou...             0
# 2761        https://www.listcorp.com/asx/cvo/cover-more             0
# 2762           https://www.listcorp.com/asx/ays/amaysim             0
# 2763  https://www.listcorp.com/asx/bal/bellamys-aust...             0
# 2764     https://www.listcorp.com/asx/det/dealt-limited             0
#
#       Last trade  Change  %Change            Sector
# 0          43.36   -1.07    -2.41         Materials
# 1          97.82   -0.93    -0.94        Financials
# 2         236.80    3.71     1.59       Health Care
# 3          28.56   -0.09    -0.31        Financials
# 4          25.22   -0.05    -0.20        Financials
# ...          ...     ...      ...               ...
# 2760        0.00    0.00     0.00         Materials
# 2761        0.00    0.00     0.00        Financials
# 2762        0.00    0.00     0.00         Utilities
# 2763        0.00    0.00     0.00  Consumer Staples
# 2764        0.00    0.00     0.00       Real Estate
#
# [2765 rows x 8 columns]

# %%
# Create NASDAQ DataFrame
nasdaq_df = pd.read_csv(nasdaq_path)
nasdaq_df
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $109.23
# 1        AA                    Alcoa Corporation Common Stock     $24.01
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    $10.76
# 3      AACG   ATA Creativity Global American Depositary Shares     $1.05
# 4      AACI            Armada Acquisition Corp. I Common Stock    $10.69
# ...     ...                                                ...       ...
# 7409   ZVRA               Zevra Therapeutics Inc. Common Stock     $4.21
# 7410   ZVSA             ZyVersa Therapeutics Inc. Common Stock   $0.1254
# 7411    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $25.59
# 7412   ZYME                        Zymeworks Inc. Common Stock     $7.19
# 7413   ZYXI                            Zynex Inc. Common Stock     $7.34
#
#       Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0        -0.2800  -0.256%  3.195931e+10  United States    1999.0  2367325
# 1        -0.2300  -0.949%  4.284575e+09  United States    2016.0  9203147
# 2         0.0000    0.00%  7.597018e+08            NaN    2021.0    22059
# 3         0.0200   1.942%  3.320328e+07          China    2008.0     2014
# 4         0.0000    0.00%  0.000000e+00  United States    2021.0      133
# ...          ...      ...           ...            ...       ...      ...
# 7409     -0.1600  -3.661%  1.428564e+08  United States       NaN   163100
# 7410     -0.0027  -2.108%  3.874131e+06  United States    2022.0  1556183
# 7411     -0.1900  -0.737%  4.425733e+09  United States    2012.0  2460935
# 7412     -0.0200  -0.277%  4.876739e+08  United States       NaN   273671
# 7413     -0.3200  -4.178%  2.636933e+08  United States       NaN   367087
#
#            Sector                                           Industry
# 0     Industrials                                Electrical Products
# 1     Industrials                                           Aluminum
# 2     Industrials                                 Metal Fabrications
# 3     Real Estate                            Other Consumer Services
# 4         Finance                                       Blank Checks
# ...           ...                                                ...
# 7409  Health Care         Biotechnology: Pharmaceutical Preparations
# 7410  Health Care         Biotechnology: Pharmaceutical Preparations
# 7411  Industrials                    Industrial Machinery/Components
# 7412  Health Care         Biotechnology: Pharmaceutical Preparations
# 7413  Health Care  Biotechnology: Electromedical & Electrotherape...
#
# [7414 rows x 11 columns]
